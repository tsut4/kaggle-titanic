# %%
from google.colab import drive
drive.mount('/content/gdrive' , force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os
import json
f = open("/content/gdrive/MyDrive/workspace/kaggle/titanic/kaggle.json", 'r')
json_data = json.load(f)
os.environ['KAGGLE_USERNAME'] = json_data['username']
os.environ['KAGGLE_KEY'] = json_data['key']

# %%
# !kaggle competitions download -c titanic
# Out:
# ...
#   0% 0.00/34.1k [00:00<?, ?B/s]
# 100% 34.1k/34.1k [00:00<00:00, 52.5MB/s]

# %%
# !mv  titanic.zip /content /content/gdrive/MyDrive/workspace/kaggle/titanic
# Out:
# mv: cannot stat 'titanic.zip': No such file or directory
# mv: inter-device move failed: '/content' to '/content/gdrive/MyDrive/workspace/kaggle/titanic/content'; unable to remove target: Directory not empty

# %%
# !cd /content/gdrive/MyDrive/workspace/kaggle/titanic

# %%
# !unzip /content/gdrive/MyDrive/workspace/kaggle/titanic/titanic.zip
# Out:
# Archive:  /content/gdrive/MyDrive/workspace/kaggle/titanic/titanic.zip
#   inflating: gender_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
# !mv /content/sample_data /content/gdrive/MyDrive/workspace/kaggle/titanic/.
